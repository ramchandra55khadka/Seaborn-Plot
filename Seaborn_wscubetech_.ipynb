# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
var=sns.load_dataset("planets")
var
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
# //for line plot

# %%
sns.lineplot(x=var.mass,y=var.distance)
plt.show()

# %%
sns.lineplot(x="mass",y="year",data=var)
plt.show()

# %%
# //for histogram

# %%
var
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
sns.displot(var["mass"],kde=True,rug=True,color='r')
plt.show()

# %%
#Barchaart

# %%
var1=sns.load_dataset("flights");
var1
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.barplot(x="year",y="passengers",data=var1)
plt.show()

# %%
sns.barplot(x="year",y="passengers",data=var1,hue="month")
plt.show()

# %%
#Heat Map

# %%
var=np.linspace(1,10,20).reshape(4,5)
var
# Out:
# array([[ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684],
#        [ 3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789],
#        [ 5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895],
#        [ 8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ]])

# %%
sns.heatmap(var)
plt.show()

# %%
data=sns.load_dataset("anagrams")
data
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
#Count PLot-it give main plot of given data.

# %%
var=sns.load_dataset("tips")
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x="sex",data=var)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(y="smoker",data=var)
# Out:
# <Axes: xlabel='count', ylabel='smoker'>

# %%
sns.countplot(x="sex",data=var,hue="smoker" ,color="red")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12828\1836686833.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.countplot(x="sex",data=var,hue="smoker" ,color="red")

# %%
#violin Plot

# %%
var=sns.load_dataset("tips")
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x="day",y="total_bill",data=var)
plt.show()

# %%
sns.violinplot(x="day",y="total_bill",data=var,hue="sex")
plt.show()

# %%
sns.violinplot(x="day",y="tip",data=var,hue="sex")
plt.show()

# %%
sns.violinplot(x="day",y="total_bill",data=var,hue="time",split=True)
plt.show()

# %%
sns.violinplot(x="day",y="total_bill",data=var,hue="time",split=True,scale="width")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12828\993780849.py:1: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   sns.violinplot(x="day",y="total_bill",data=var,hue="time",split=True,scale="width")

# %%
sns.violinplot(x="total_bill",data=var)
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.violinplot(y="total_bill",data=var)
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# #Pair PLot

# %%
var=sns.load_dataset("healthexp")
var
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
sns.pairplot(var)
plt.show()

# %%
sns.pairplot(var,hue="Country")
plt.show()

# %%
var=sns.load_dataset("tips")
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#Strip Plot

# %%
sns.stripplot(x="day",y="total_bill",data=var)
plt.show()

# %%
sns.stripplot(x="day",y="total_bill",data=var,hue="sex")
plt.show()

# %%
sns.stripplot(x="day",y="total_bill",data=var,hue="sex",palette="rocket_r",linewidth=1,edgecolor="red")
plt.show()

# %%
sns.stripplot(x="day",y="total_bill",data=var,hue="sex",palette="rocket_r",linewidth=1,edgecolor="red",jitter=3,size=5)
plt.show()

# %%
sns.stripplot(x="day",y="total_bill",data=var,hue="sex",palette="rocket_r",linewidth=1,edgecolor="red",size=6)
plt.show()

# %%
sns.stripplot(x=var["total_bill"])
# Out:
# <Axes: xlabel='total_bill'>

# %%
#Box Plot

# %%
v1=sns.load_dataset("tips")
v1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=v1)
plt.show()

# %%
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=v1,hue="time")
plt.show()

# %%
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=v1,hue="sex",color="g")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15184\1820471012.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:g'` for the same effect.
#
#   sns.boxplot(x="day",y="total_bill",data=v1,hue="sex",color="g")

# %%
sns.set(style="whitegrid")
sns.boxplot(x="day",y="total_bill",data=v1,hue="sex",showmeans=True,palette="plasma")
plt.show()

# %%
sns.set(style="whitegrid")
sns.boxplot(x=v1["total_bill"])
plt.show()

# %%
#cat plot

# %%
var=sns.load_dataset("tips")
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x="tip", y="size", data=var)  
plt.show()

# %%
sns.catplot(x="tip", y="size", data=var,hue="sex",kind="box",palette="Oranges")  
plt.show()

# %%
sns.catplot(x="day", y="size", data=var,hue="sex",kind="bar",palette="Oranges")  
plt.show()

# %%
sns.catplot(x="day", y="size", data=var,hue="sex",kind="point",palette="Oranges")  
plt.show()
